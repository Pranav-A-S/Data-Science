# %% [markdown]
# 1.	Import data and save it in your disk space.

# %%
import pandas as pd
df = pd.read_csv('/content/IoTBotNetDataset.csv')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (7,9) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# 2.	 Drop the columns not required for your analysis.

# %%
df = df.drop("sport", axis='columns')
df
# Out:
#          pkSeqID         stime flags  flgs_number proto  proto_number  \
# 0            1.0  1.528089e+09     e          1.0   tcp           1.0
# 1            2.0  1.528089e+09     e          1.0   arp           2.0
# 2            3.0  1.528089e+09     e          1.0   UDP           1.0
# 3            4.0  1.528089e+09     i          1.0   tcp           1.0
# 4            5.0  1.528089e+09     e          1.0   UDP           1.0
# ...          ...           ...   ...          ...   ...           ...
# 998548  998549.0  1.528085e+09     e          1.0   udp           3.0
# 998549  998550.0  1.528085e+09     e          1.0   udp           3.0
# 998550  998551.0  1.528085e+09     e          1.0   udp           3.0
# 998551  998552.0  1.528085e+09     e          1.0   udp           3.0
# 998552  998553.0  1.528085e+09     e          1.0   udp           3.0
#
#                   saddr            daddr dport  pkts  ...  AR_P_Proto_P_DstIP  \
# ...

# %% [markdown]
# 3.	 Do a missing value analysis and perform appropriate steps to correct them

# %%
df.notnull()
# Out:
#         pkSeqID  stime  flags  flgs_number  proto  proto_number  saddr  daddr  \
# 0          True   True   True         True   True          True   True   True
# 1          True   True   True         True   True          True   True   True
# 2          True   True   True         True   True          True   True   True
# 3          True   True   True         True   True          True   True   True
# 4          True   True   True         True   True          True   True   True
# ...         ...    ...    ...          ...    ...           ...    ...    ...
# 998548     True   True   True         True   True          True   True   True
# 998549     True   True   True         True   True          True   True   True
# 998550     True   True   True         True   True          True   True   True
# 998551     True   True   True         True   True          True   True   True
# 998552     True   True   True         True   True          True   True   True
#
# ...

# %%
df.isnull()
# Out:
#         pkSeqID  stime  flags  flgs_number  proto  proto_number  saddr  daddr  \
# 0         False  False  False        False  False         False  False  False
# 1         False  False  False        False  False         False  False  False
# 2         False  False  False        False  False         False  False  False
# 3         False  False  False        False  False         False  False  False
# 4         False  False  False        False  False         False  False  False
# ...         ...    ...    ...          ...    ...           ...    ...    ...
# 998548    False  False  False        False  False         False  False  False
# 998549    False  False  False        False  False         False  False  False
# 998550    False  False  False        False  False         False  False  False
# 998551    False  False  False        False  False         False  False  False
# 998552    False  False  False        False  False         False  False  False
#
# ...

# %%
df.fillna(method='ffill')
# Out:
#          pkSeqID         stime flags  flgs_number proto  proto_number  \
# 0            1.0  1.528089e+09     e          1.0   tcp           1.0
# 1            2.0  1.528089e+09     e          1.0   arp           2.0
# 2            3.0  1.528089e+09     e          1.0   UDP           1.0
# 3            4.0  1.528089e+09     i          1.0   tcp           1.0
# 4            5.0  1.528089e+09     e          1.0   UDP           1.0
# ...          ...           ...   ...          ...   ...           ...
# 998548  998549.0  1.528085e+09     e          1.0   udp           3.0
# 998549  998550.0  1.528085e+09     e          1.0   udp           3.0
# 998550  998551.0  1.528085e+09     e          1.0   udp           3.0
# 998551  998552.0  1.528085e+09     e          1.0   udp           3.0
# 998552  998553.0  1.528085e+09     e          1.0   udp           3.0
#
#                   saddr            daddr dport  pkts  ...  AR_P_Proto_P_DstIP  \
# ...

# %% [markdown]
# 4.	Perform an outlier analysis for any two columns

# %%
df.boxplot(by ='proto', column =['mean'], grid = False)
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))

# %% [markdown]
# 5.	Do a correlation analysis of any two variables

# %%
a=df['rate'].corr(df['srate'])
a
# Out:
# 0.18904714981030551

# %% [markdown]
# 6.	Describe the data

# %%
df.describe()
# Out:
#              pkSeqID         stime    flgs_number   proto_number  \
# count  996297.000000  9.962970e+05  996297.000000  996294.000000
# mean   500191.103927  1.528083e+09       1.808430       1.765398
# std    287942.231266  1.754173e+03       1.107501       0.972087
# min         1.000000  1.528081e+09       1.000000       1.000000
# 25%    251331.000000  1.528081e+09       1.000000       1.000000
# 50%    500405.000000  1.528081e+09       2.000000       1.000000
# 75%    749479.000000  1.528085e+09       2.000000       3.000000
# max    998553.000000  1.528089e+09       6.000000       4.000000
#
#                 pkts          bytes   state_number         ltime  \
# count  996297.000000  996297.000000  996297.000000  9.962970e+05
# mean        6.520403     614.684976       2.826334  1.528083e+09
# std         8.634993     605.434762       1.210459  1.752839e+03
# min         1.000000     120.000000       1.000000  1.528081e+09
# ...

# %% [markdown]
# 7.	Display the first 3 rows

# %%
df.head(3)
# Out:
#    pkSeqID         stime flags  flgs_number proto  proto_number  \
# 0      1.0  1.528089e+09     e          1.0   tcp           1.0
# 1      2.0  1.528089e+09     e          1.0   arp           2.0
# 2      3.0  1.528089e+09     e          1.0   UDP           1.0
#
#              saddr            daddr dport  pkts  ...  AR_P_Proto_P_DstIP  \
# 0  192.168.100.147    192.168.100.7    80   8.0  ...             1.12704
# 1    192.168.100.7  192.168.100.147    -1   2.0  ...         15267.20000
# 2  192.168.100.147    192.168.100.7    80   8.0  ...             1.12704
#
#   N_IN_Conn_P_DstIP  N_IN_Conn_P_SrcIP  AR_P_Proto_P_Sport  \
# 0              96.0               75.0            1.133720
# 1               1.0                2.0            0.005142
# 2              96.0               75.0            1.135100
#
#    AR_P_Proto_P_Dport  Pkts_P_State_P_Protocol_P_DestIP  \
# 0            1.129970                             770.0
# 1            0.005142                               2.0
# ...

# %% [markdown]
# 8.	Display the last 4 rows

# %%
df.tail(4)
# Out:
#          pkSeqID         stime flags  flgs_number proto  proto_number  \
# 998549  998550.0  1.528085e+09     e          1.0   udp           3.0
# 998550  998551.0  1.528085e+09     e          1.0   udp           3.0
# 998551  998552.0  1.528085e+09     e          1.0   udp           3.0
# 998552  998553.0  1.528085e+09     e          1.0   udp           3.0
#
#                   saddr          daddr dport  pkts  ...  AR_P_Proto_P_DstIP  \
# 998549  192.168.100.149  192.168.100.5    80   7.0  ...            0.269102
# 998550  192.168.100.149  192.168.100.5    80   7.0  ...            0.269102
# 998551  192.168.100.149  192.168.100.5    80   7.0  ...            0.269102
# 998552  192.168.100.149  192.168.100.5    80   7.0  ...            0.269102
#
#        N_IN_Conn_P_DstIP  N_IN_Conn_P_SrcIP  AR_P_Proto_P_Sport  \
# 998549             100.0              100.0            0.269107
# 998550             100.0              100.0            0.269107
# ...

# %% [markdown]
# 9.	Locate the first row corresponding to the proto as “UDP”

# %%
df = pd.DataFrame(df)
df.loc[df['proto']=="UDP"].head(1)
# Out:
#    pkSeqID         stime flags  flgs_number proto  proto_number  \
# 2      3.0  1.528089e+09     e          1.0   UDP           1.0
#
#              saddr          daddr dport  pkts  ...  AR_P_Proto_P_DstIP  \
# 2  192.168.100.147  192.168.100.7    80   8.0  ...             1.12704
#
#   N_IN_Conn_P_DstIP  N_IN_Conn_P_SrcIP  AR_P_Proto_P_Sport  \
# 2              96.0               75.0              1.1351
#
#    AR_P_Proto_P_Dport  Pkts_P_State_P_Protocol_P_DestIP  \
# 2             1.12997                             770.0
#
#    Pkts_P_State_P_Protocol_P_SrcIP  attack  category  subcategory
# 2                            602.0     1.0       DoS         HTTP
#
# [1 rows x 45 columns]

# %% [markdown]
# 10.	How many rows of data do you have?

# %%
len(df)
# Out:
# 998553

# %% [markdown]
# 11.	Display the first 5 columns of the first row

# %%
df.iloc[1][0:5]
# Out:
# pkSeqID                 2.0
# stime          1528088522.0
# flags                     e
# flgs_number             1.0
# proto                   arp
# Name: 1, dtype: object

# %% [markdown]
# 12.	Count the number of packets affected  based on flags as “i”

# %%
df.loc[df["flags"]=='i']["pkts"].value_counts()
# Out:
# 8.0    30
# Name: pkts, dtype: int64

# %% [markdown]
# #13#1

# %%
x=df.loc[df['stime'] == 1528088522, 'pkts'].mean()
y=df.loc[df['stime'] == 1528088522, 'sbytes'].mean()
z=df.loc[df['stime'] == 1528088522, 'dbytes'].mean()
print(x,y,z)
# Out:
# 8.069204152249135 792.7923875432526 1001.9480968858131

# %% [markdown]
# 13. Split the traffic based on traffic into two groups Group 1: pkts<=10 and Group 2:pkts>10

# %%
pk = df.loc[df['pkts'].loc[:]>10,:]
print('Packets which are greater than 10')
print(pk)
low = df.loc[df['pkts'].loc[:]<=10,:]
print('Packets less than or equal to 10')
print(low)
# Out:
# Packets which are greater than 10
#          pkSeqID         stime flags  flgs_number proto  proto_number  \
# 144        145.0  1.528089e+09   e s          2.0   tcp           1.0
# 276        277.0  1.528089e+09   e s          2.0   tcp           1.0
# 277        278.0  1.528089e+09   e s          2.0   UDP           1.0
# 278        279.0  1.528089e+09   e s          2.0   UDP           1.0
# 283        284.0  1.528089e+09   e s          2.0   tcp           1.0
# ...          ...           ...   ...          ...   ...           ...
# 998213  998214.0  1.528085e+09     e          1.0   udp           3.0
# 998214  998215.0  1.528085e+09     e          1.0   udp           3.0
# 998215  998216.0  1.528085e+09     e          1.0   udp           3.0
# 998216  998217.0  1.528085e+09     e          1.0   udp           3.0
# 998217  998218.0  1.528085e+09     e          1.0   udp           3.0
#
#                   saddr          daddr dport  pkts  ...  AR_P_Proto_P_DstIP  \
# ...

# %% [markdown]
# 14.	Compute the mean and the variance of " Pkts_PState_P_Protocol_P_DestIP” for subcategory as HTTP and TCP

# %%
df.loc[df['subcategory'] =='HTTP', 'Pkts_P_State_P_Protocol_P_DestIP'].mean()
# Out:
# 746.0976430976431

# %%
df.loc[df['subcategory'] =='HTTP', 'Pkts_P_State_P_Protocol_P_DestIP'].var()
# Out:
# 60446.44800657065

# %%
df.loc[df['subcategory'] =='TCP', 'Pkts_P_State_P_Protocol_P_DestIP'].mean()
# Out:
# 329.8424106502549

# %%
df.loc[df['subcategory'] =='TCP', 'Pkts_P_State_P_Protocol_P_DestIP'].var()
# Out:
# 21456.481203437987

# %% [markdown]
# 15.	Draw a histogram for packets with stime as 1528088521, 1528088522., 1528088523. Histogram should be step-filled with bin of size 20. Find the skew of this distribution, and comment if it is positive or negative

# %%
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f2fa04e5c10>,
# ...
#       dtype=object)
